# %% [markdown]
# # 7.赋值语句

# %% [markdown]
# ## 7.1 赋值语句在Python中的重要地位

# %%
i=1
i
# Out:
# 1

# %% [markdown]
# ## 7.2 链式赋值语句

# %%
i=j=2 
i
j
# Out:
# 2

# %%
j=2
i=j
i
j
# Out:
# 2

# %% [markdown]
# ## 7.3 复合赋值语句

# %%
i=1
i+=20
i
# Out:
# 21

# %%
#













#

# %% [markdown]
# ## 7.4 序列的拆包式赋值

# %%
a,b,c=1,2,3
a,b,c
# Out:
# (1, 2, 3)

# %% [markdown]
# ## 7.5 两个变量值的调换

# %%
a=1
b=2
a,b=b,a
a,b
# Out:
# (2, 1)
